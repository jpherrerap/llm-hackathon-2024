# %%
import re
from typing import List, Tuple
from urllib.parse import urljoin
import json
from pathlib import Path

import requests
from bs4 import BeautifulSoup, NavigableString
from langchain.agents import AgentType, initialize_agent, create_react_agent
from langchain.chat_models import ChatOpenAI

from langchain.schema import HumanMessage, SystemMessage
from langchain.tools import Tool
from langchain_core.tools import tool

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from dotenv import load_dotenv
from typing import Annotated, List


import os

load_dotenv()
# Out:
# True

# %%
# Prompt sin usar
system_prompt = '''Assistant es un gran modelo de lenguaje entrenado por OpenAI.

Assistant está diseñado para ayudar en una amplia gama de tareas, desde responder a preguntas sencillas hasta proporcionar explicaciones detalladas y debates sobre una gran variedad de temas. Como modelo lingüístico, Assistant es capaz de generar textos similares a los humanos a partir de la información que recibe, lo que le permite entablar conversaciones naturales y ofrecer respuestas coherentes y relevantes para el tema en cuestión.

Assistant aprende y mejora constantemente, y sus capacidades evolucionan sin cesar. Es capaz de procesar y comprender grandes cantidades de texto, y puede utilizar este conocimiento para proporcionar respuestas precisas e informativas a una amplia gama de preguntas.             Además, Assistant es capaz de generar su propio texto a partir de la información que recibe, lo que le permite participar en debates y ofrecer explicaciones y descripciones sobre una amplia gama de temas.

En general, Assistant es un potente sistema que puede ayudarte con una gran variedad de tareas y proporcionarte valiosos conocimientos e información sobre una amplia gama de temas. Tanto si necesitas ayuda con una pregunta concreta como si sólo quieres mantener una conversación sobre un tema en particular, Assistant está aquí para ayudarte.'''


human_prompt = '''HERRAMIENTAS
------
Assistant puede pedir al usuario que utilice herramientas para buscar información que pueda ser útil para responder a la pregunta original del usuario. Las herramientas que el humano puede utilizar son:

{tools}

INSTRUCCIONES DE FORMATO DE RESPUESTA
----------------------------

Cuando me responda, por favor envíe una respuesta en uno de estos dos formatos:

**Opción 1:**
Utilice esta opción si desea que el humano utilice una herramienta.
Fragmento de código Markdown formateado en el siguiente esquema:

```json
{{
    "action": string, \ La acción a tomar. Debe ser uno de {tool_names}.
    "action_input": cadena \ La entrada de la acción
}}
```

**Opción #2:**
Utilice esta opción si desea responder directamente al humano. Markdown fragmento de código formateado en el siguiente esquema:

```json
{{
    "action": "Respuesta final",
    "action_input": string \ Usted debe poner lo que desea volver a utilizar aquí
}}
```

ENTRADA DEL USUARIO
--------------------
Aquí está el input del usuario (recuerda responder con un fragmento de código markdown de un blob json con una única acción, y NADA más):

{input}'''

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder("chat_history", optional=True),
        ("human", human_prompt),
        MessagesPlaceholder("agent_scratchpad"),
    ]
)

# %%
# También sin uso
json_schema ={
  "title": "Faq",
  "description": "Lista de objetos JSON de pares 'question' y 'answer'",
  "type": "object",
  "properties": {
    "faq": {
      "type": "array",
      "description": "Lista de objetos JSON de pares 'question' y 'answer'",
      "items": {
        "type": "object",
        "properties": {
          "question": {
            "type": "string",
            "description": "Pregunta inferida del texto"
          },
          "answer": {
            "type": "string",
            "description": "Contenido del texto que responde a una pregunta"
          }
        },
        "required": ["question", "answer"]
      }
    }
  },
  "required": ["faq"]
}

# %%
# @tool("Agrupar texto en formato pregunta-respuesta")
def group_text(text: str) -> List[dict]:
    """
    Agrupa texto en una lista de objetos JSON con formato question-answer
    """
    llm = ChatOpenAI(temperature=0.1, model="gpt-4o-mini", openai_api_key=os.environ["OPENAI_API_KEY"])
    # llm = llm.bind_structured_output(json_schema)
    prompt = ChatPromptTemplate.from_messages([("system", "Del siguiente texto, para cada punto escribe una pregunta respondida por el texto. Luego entrega una lista de objetos JSON con atributos 'question' y 'answer'. Donde 'question' es la pregunta y 'answer' es la respuesta tomada tal como aparece en el texto. A continuación, el texto (recuerda responder con un fragmento de código markdown de un blob json con una única acción, y NADA más): \n\n {text}")])
    chain = prompt | llm
    grouped_text = chain.invoke({"text": text})
    parsed_qas = "".join(grouped_text.content.split('\n')[1:-1])
    # print(parsed_qas)
    question_answer_list = json.loads(parsed_qas)
    return question_answer_list

# %%
class FAQScraper:
    def __init__(self, base_url: str, model: str, openai_api_key: str):
        self.base_url = base_url
        self.visited_urls = set()
        self.results = []
        self.openai_api_key = openai_api_key

        # Initialize LangChain agent
        self.model = model
        self.llm = ChatOpenAI(temperature=0, model=self.model, openai_api_key=openai_api_key)
        tools = [self._group_text]
        self.agent = create_react_agent(self.llm, tools, prompt=prompt)

    def scrape(self, start_url: str, max_depth: int = 2) -> List[dict]:
        self._scrape_recursive(start_url, max_depth)
        return self.results
    
    def scrape_page(self, url: str) -> str:
        response = requests.get(url, timeout=10)  # Add a 30-second timeout
        soup = BeautifulSoup(response.text, 'html.parser')
        text_content = soup.get_text(separator='\n', strip=True)
        topic = text_content.split('\n')[0].split('|')[0].strip()
        # relevant_text = self.agent.run(f"Extrae del siguiente texto el contenido relacionado con el tema específico '{topic}', luego agrupa el contenido en un JSON en formato pregunta-respuesta:   \n\n{text_content}")
        grouped_text = group_text(text_content)
        # grouped_text = relevant_text
        return grouped_text
    
    def _extract_relevant_text(self, text_content: str, topic: str) -> str:
        relevant_text = self.llm.invoke(f"Extrae del siguiente texto el contenido relacionado con el tema específico '{topic}', solamente entrega el contenido relevante  \n\n{text_content}").content
        return relevant_text
    

    def _scrape_recursive(self, url: str, max_depth: int = 2, current_depth: int = 0):
        if url in self.visited_urls:
            return

        self.visited_urls.add(url)
        print(f"Scraping URL: {url}")
        response = requests.get(url, timeout=10)  # Add a 30-second timeout
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract text content
        text_content = soup.get_text(separator='\n', strip=True)
        topic = text_content.split('\n')[0].split('|')[0].strip()

        # Use LangChain agent to group text
        relevant_text = self.llm.invoke(f"Extrae del siguiente texto el contenido relacionado con el siguiente tema: {topic}, solamente entrega el texto  \n\n{text_content}").content
        question_answer_list = []
        try:
            question_answer_list = self._group_text(relevant_text)
        except Exception as e:
            try:
                question_answer_list = self._group_text(relevant_text)
            except Exception as e:
                print(f"Error grouping text from url {url}: {e}")
        
        for qa in question_answer_list:
            qa["category"] = topic
        
        self.results.extend(question_answer_list)

        # Find and follow links
        if current_depth >= max_depth:
            return
        
        for link in soup.find_all('a', href=True):
            href = link['href'].split('?')[0]
            full_url = urljoin(url, href)
            if full_url.startswith(self.base_url) and full_url not in self.visited_urls:
                self._scrape_recursive(full_url, current_depth + 1, max_depth)

    def to_json(self, filename: str):
        db_knowledge = json.loads(Path(filename).read_text())
        db_knowledge["faq"].extend(self.results)
        Path(filename).write_text(json.dumps(db_knowledge, indent=2, ensure_ascii=False))


    @tool("Agrupar texto en formato pregunta-respuesta")
    def _group_text(text: str) -> List[dict]:
        """
        Agrupa texto en una lista de objetos JSON con formato question-answer
        """
        llm = ChatOpenAI(temperature=0.1, model="gpt-4o-mini", openai_api_key=os.environ["OPENAI_API_KEY"])
        prompt = ChatPromptTemplate.from_messages([("system", "Del siguiente texto, para cada punto escribe una pregunta respondida por el texto. Luego entrega una lista de objetos JSON con atributos 'question' y 'answer'. Donde 'question' es la pregunta y 'answer' es la respuesta tomada tal como aparece en el texto. A continuación, el texto (recuerda responder con un fragmento de código markdown de un blob json con una única acción, y NADA más): \n\n {text}")])
        chain = prompt | llm
        grouped_text = chain.invoke({"text": text})
        parsed_qas = "".join(grouped_text.content.split('\n')[1:-1])
        question_answer_list = json.loads(parsed_qas)
        return question_answer_list

# %%
start_url = "https://www.falabella.com/falabella-cl/page/contactanos"
example_url = "https://www.falabella.com/falabella-cl/page/cambios-reemplazos"

scraper = FAQScraper(
    base_url="https://www.falabella.com/falabella-cl/page/",
    model="gpt-4o-mini",
    openai_api_key=os.environ["OPENAI_API_KEY"])

result = scraper.scrape(start_url, max_depth=2)
scraper.to_json("db_knowledge.json")
# Out:
# Scraping URL: https://www.falabella.com/falabella-cl/page/contactanos
# Scraping URL: https://www.falabella.com/falabella-cl/page/Vende-en-Falabella.com
# Scraping URL: https://www.falabella.com/falabella-cl/page/Cambios-y-Devoluciones
# Scraping URL: https://www.falabella.com/falabella-cl/page/consultas-boletas-facturas
# Scraping URL: https://www.falabella.com/falabella-cl/page/ganadores-concursos
# Scraping URL: https://www.falabella.com/falabella-cl/page/canal-de-integridad
# Scraping URL: https://www.falabella.com/falabella-cl/page/proteccion-de-datos
# Scraping URL: https://www.falabella.com/falabella-cl/page/venta-empresa-falabella
# Scraping URL: https://www.falabella.com/falabella-cl/page/cyber-monday
# Scraping URL: https://www.falabella.com/falabella-cl/page/Black-Friday
# Scraping URL: https://www.falabella.com/falabella-cl/page/cyber-day
# Scraping URL: https://www.falabella.com/falabella-cl/page/falabella-retail
# Scraping URL: https://www.falabella.com/falabella-cl/page/comprar-terminos-condiciones
# Scraping URL: https://www.falabella.com/falabella-cl/page/comprar-politica-cookies
# Scraping URL: https://www.falabella.com/falabella-cl/page/comprar-politica-privacidad
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[245], line 10
#       4 scraper = FAQScraper(
#       5     base_url="https://www.falabella.com/falabella-cl/page/",
#       6     model="gpt-4o-mini",
#       7     openai_api_key=os.environ["OPENAI_API_KEY"])
#       9 result = scraper.scrape(start_url, max_depth=2)
# ---> 10 scraper.to_json("db_knowledge.json")
#
# Cell In[244], line 73, in FAQScraper.to_json(self, filename)
#      72 def to_json(self, filename: str):
# ---> 73     db_knowledge = json.loads(Path(filename).read_text())
#      74     db_knowledge["faq"].extend(self.results)
#      75     Path(filename).write_text(json.dumps(db_knowledge, indent=2, ensure_ascii=False))
#
# File ~/miniconda3/envs/vue-chatbot/lib/python3.11/pathlib.py:1058, in Path.read_text(self, encoding, errors)
#    1054 """
#    1055 Open the file in text mode, read it, and close the file.
#    1056 """
#    1057 encoding = io.text_encoding(encoding)
# -> 1058 with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1059     return f.read()
#
# File ~/miniconda3/envs/vue-chatbot/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'db_knowledge.json'

# %%
scraper.results
# Out:
# [{'question': '¿Qué puedo hacer en el centro de ayuda?',
#   'answer': 'Revisa y gestiona tus pedidos, Sigue tus compras, Cancela tus pedidos, Haz tus solicitudes de devolución, Revisa tus boletas y tickets de cambio, Ingresa tus casos.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Cómo puedo contactar al centro de ayuda?',
#   'answer': 'Llámanos 600 329 2002.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Cuáles son los horarios para hablar por teléfono?',
#   'answer': 'Hablemos de lunes a sábados de 09:00 a 19:00 h.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Puedo hablar por WhatsApp?',
#   'answer': 'Hablemos por WhatsApp.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Qué número debo llamar para comprar por teléfono?',
#   'answer': 'Compremos por teléfono 600 390 6500.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Cuáles son los horarios para comprar por teléfono?',
#   'answer': 'Te ayudamos a comprar de lunes a sábados de 09:00 a 22:00 h. domingos y festivos de 09:00 a 21:00 h.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Dónde puedo resolver dudas sobre Club Novios, Club Bebé o Club Deco?',
#   'answer': '¿Dudas con Club Novios, Club Bebé o Club Deco? +562 2380 0256.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Cuáles son los horarios para dudas sobre Club Novios, Club Bebé o Club Deco?',
#   'answer': 'Hablemos de lunes a sábados de 09:00 a 19:00 h.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Dónde puedo resolver dudas sobre Banco Falabella o Tarjeta CMR?',
#   'answer': 'Escríbenos a nuestro WhatsApp, disponible las 24 horas.',
#   'category': 'Centro de ayuda'},
#  {'question': '¿Por qué vender en falabella.com?',
#   'answer': '+180 millones de visitas mensuales regionales',
#   'category': 'Vende en falabella.com'},
#  {'question': '¿Cuánto han crecido las ventas desde 2019?',
#   'answer': 'Crecimiento de las ventas en x2,8 veces desde 2019',
#   'category': 'Vende en falabella.com'},
#  {'question': '¿Cuántos clientes hay a nivel regional?',
#   'answer': '37 millones de clientes a nivel regional',
#   'category': 'Vende en falabella.com'},
#  {'question': '¿Qué beneficios obtengo al vender en falabella.com?',
#   'answer': 'Mayor visibilidad para tu marca',
#   'category': 'Vende en falabella.com'},
#  {'question': '¿Qué herramientas ofrece Falabella Seller Center?',
#   'answer': 'Autogestionable y llena de herramientas para tomar las mejores decisiones',
#   'category': 'Vende en falabella.com'},
#  {'question': '¿Qué servicios financieros puedo acceder como seller?',
#   'answer': 'Accede a servicios financieros como seller a través de Fpay',
#   'category': 'Vende en falabella.com'},
#  {'question': '¿Cómo devuelvo un producto?',
#   'answer': 'Es gratuito, solo debes entregar el producto tal y como lo recibiste, con todas sus etiquetas.',
#   'category': 'Devoluciones y cambios'},
#  {'question': '¿Cómo cambio o reemplazo un producto?',
#   'answer': 'Cambiar de opinión está bien. Si necesitas devolver o cambiar un producto aquí te contamos lo que tienes que hacer, dependiendo de su tamaño.',
#   'category': 'Devoluciones y cambios'},
#  {'question': '¿Cuáles son los plazos de reembolso de dinero?',
#   'answer': 'Es gratuito, solo debes entregar el producto tal y como lo recibiste, con todas sus etiquetas.',
#   'category': 'Devoluciones y cambios'},
#  {'question': '¿Qué productos tienen condiciones especiales?',
#   'answer': 'Cambiar de opinión está bien. Si necesitas devolver o cambiar un producto aquí te contamos lo que tienes que hacer, dependiendo de su tamaño.',
#   'category': 'Devoluciones y cambios'},
#  {'question': '¿Dónde puedo encontrar mis boletas y facturas si compré con mi cuenta falabella.com?',
#   'answer': 'si compras con tu cuenta falabella.com siempre podrás encontrar tus boletas y facturas a través de Mis compras.',
#   'category': 'Boletas y facturas'},
#  {'question': '¿Qué debo hacer si compré como invitado y quiero recuperar mi boleta o factura?',
#   'answer': 'elige el vendedor de tu compra e ingresa unos datos para descargar una copia de tu boleta o factura.',
#   'category': 'Boletas y facturas'},
#  {'question': '¿Qué opciones tengo para recuperar boletas o facturas vendidas por Falabella?',
#   'answer': 'Recuperar boleta o factura.',
#   'category': 'Boletas y facturas'},
#  {'question': '¿Qué opciones tengo para recuperar boletas o facturas vendidas por Sodimac?',
#   'answer': 'Recuperar boleta, Recuperar factura.',
#   'category': 'Boletas y facturas'},
#  {'question': '¿Qué opción tengo para recuperar boletas vendidas por Tottus?',
#   'answer': 'Recuperar boleta.',
#   'category': 'Boletas y facturas'},
#  {'question': '¿Qué se puede hacer en falabella.com?',
#   'answer': 'Vende en falabella.com',
#   'category': 'Legales de vendedores'},
#  {'question': '¿Dónde se pueden encontrar concursos y bases legales?',
#   'answer': 'Concursos y bases legales',
#   'category': 'Legales de vendedores'},
#  {'question': '¿Qué canal se menciona para la integridad?',
#   'answer': 'Canal de integridad - Integrity Channel',
#   'category': 'Legales de vendedores'},
#  {'question': '¿Cómo se protege la información de los usuarios?',
#   'answer': 'Cómo cuidamos tus datos',
#   'category': 'Legales de vendedores'},
#  {'question': '¿Qué se puede hacer para unirse a falabella?',
#   'answer': 'Sé parte de falabella.com',
#   'category': 'Legales de vendedores'},
#  {'question': '¿Dónde puedo revisar el Código de Integridad?',
#   'answer': 'Para revisar nuestro Código de Integridad, por favor haz click aquí.',
#   'category': 'Canal de integridad'},
#  {'question': '¿Qué debo hacer si quiero hacer una consulta sobre el Código de Integridad?',
#   'answer': 'Accede a nuestro Canal de Integridad.',
#   'category': 'Canal de integridad'},
#  {'question': '¿Qué puedo informar a través del Canal de Integridad?',
#   'answer': 'Informar posibles situaciones contrarias a este Código o a la normativa vigente.',
#   'category': 'Canal de integridad'},
#  {'question': '¿Para qué usamos tus datos?',
#   'answer': 'Tus datos nos ayudan a conocerte para mejorar tu experiencia.',
#   'category': 'protección de datos'},
#  {'question': '¿Cómo mejoramos tu experiencia?',
#   'answer': 'Brindándote beneficios y descuentos que se adapten a ti.',
#   'category': 'protección de datos'},
#  {'question': '¿Qué beneficios obtienes al inscribirte en CMR Puntos?',
#   'answer': '¡Siempre acumulas puntos con tus compras con cualquier medio de pago!',
#   'category': 'protección de datos'},
#  {'question': '¿Cómo mejoramos la experiencia de postventa?',
#   'answer': 'Si te conocemos mejor es más fácil resolver las consultas o inquietudes que tengas con tus compras y servicios.',
#   'category': 'protección de datos'},
#  {'question': '¿Qué ofrecemos para adaptarnos a tus necesidades?',
#   'answer': 'Ofreciéndote productos y servicios que se acomoden a tus necesidades y gustos.',
#   'category': 'protección de datos'},
#  {'question': '¿Qué debes saber sobre la seguridad de tus datos?',
#   'answer': 'Tus datos están seguros, implementamos las medidas para ello.',
#   'category': 'protección de datos'},
#  {'question': '¿Qué puedes esperar de nuestra transparencia?',
#   'answer': 'Puedes confiar en que sólo usaremos tus datos para aquello que nos has autorizado.',
#   'category': 'protección de datos'},
#  {'question': '¿Quién es el dueño de tus datos?',
#   'answer': 'Tú eres el dueño o dueña de tus datos.',
#   'category': 'protección de datos'},
#  {'question': '¿Cómo puedes ejercer tus derechos sobre tus datos?',
#   'answer': 'Tú controlas qué hacemos con tus datos ejerciendo cuando quieras los derechos que te otorga la ley.',
#   'category': 'protección de datos'},
#  {'question': '¿Dónde puedes escribir si tienes dudas sobre tus datos?',
#   'answer': 'Escríbenos a la casilla [email\xa0protected]',
#   'category': 'protección de datos'},
#  {'question': '¿Qué se puede regalar a los trabajadores?',
#   'answer': '¿Quieres regalar Gift Cards a tus trabajadores?',
#   'category': 'Venta empresa'},
#  {'question': '¿Cuáles son las formas de pago disponibles?',
#   'answer': 'Puedes comprar con transferencia electrónica y orden de compra a 30 días (previa evaluación de apertura de línea de crédito).',
#   'category': 'Venta empresa'},
#  {'question': '¿Hay despachos gratuitos?',
#   'answer': 'Contamos con despachos gratis dentro de Santiago, sujetos a disponibilidad y ubicación.',
#   'category': 'Venta empresa'},
#  {'question': '¿Se pueden obtener descuentos?',
#   'answer': 'Tendrás la opción de cotizar con descuentos.',
#   'category': 'Venta empresa'},
#  {'question': '¿Dónde se puede cotizar?',
#   'answer': 'Puedes cotizar tu pedido usando Falabella.com como catálogo (solo Productos vendidos por Falabella Retail).',
#   'category': 'Venta empresa'},
#  {'question': '¿Qué facilidades de pago se ofrecen?',
#   'answer': 'Consulta por tu Línea de Crédito para pagar con Órdenes de Compra y pago a 30 días (previa Evaluación). Además, puedes transferir tu pago a la cuenta corriente de Falabella.',
#   'category': 'Venta empresa'},
#  {'question': '¿Qué sucede si soy un Cliente Frecuente?',
#   'answer': 'Si eres un Cliente Frecuente o si tienes necesidades de volumen alto, un ejecutivo estará asignado a tu cuenta para atender y responder a tus requerimientos.',
#   'category': 'Venta empresa'},
#  {'question': '¿Cómo puedo hacer consultas y cotizaciones?',
#   'answer': 'Necesitas cotizar? Te invitamos a llenar este formulario y te contactará un ejecutivo a la brevedad.',
#   'category': 'Venta empresa'},
#  {'question': '¿Cuál es el contacto para consultas?',
#   'answer': 'Cualquier previa duda que tengas, puedes contactarnos a nuestro correo o revisar nuestras preguntas frecuentes.',
#   'category': 'Venta empresa'},
#  {'question': '¿Cuál es el número de contacto por Whatsapp?',
#   'answer': '+56994891940',
#   'category': 'Venta empresa'},
#  {'question': '¿Cuál es el número de venta telefónica?',
#   'answer': 'Venta telefónica 600 390 6500',
#   'category': 'Venta empresa'},
#  {'question': '¿Qué evento se espera para el 2024?',
#   'answer': 'la nueva edición de Cyber Monday 2024',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Qué tipo de promociones se mencionan para Cyber Monday?',
#   'answer': 'grandes sorpresas, promociones y descuentos preparados especialmente para ti',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Dónde se pueden encontrar ofertas durante todo el año?',
#   'answer': 'en tus marcas favoritas',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Qué ventajas se mencionan sobre comprar online?',
#   'answer': 'las ventajas de comprar online en falabella.com',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Qué productos se destacan en las ofertas?',
#   'answer': 'iPhones, moda mujer, aire acondicionado, secadoras, parrillas, abrigos mujer y mucho más',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Qué se puede hacer al descargar la app de falabella.com?',
#   'answer': 'encontrar ofertas increíbles',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Qué beneficios ofrece la app de falabella.com?',
#   'answer': 'Recibe ofertas primero, activa tus notificaciones y recibe ofertas, promociones y descuentos que tenemos para ti',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Qué información se debe saber sobre Cyber Monday?',
#   'answer': 'nuestras tiendas Cybermonday Chile',
#   'category': 'Cyber Monday 2024 ⚡ Ofertas'},
#  {'question': '¿Cuándo es el próximo Black Friday?',
#   'answer': 'Black Friday 2024',
#   'category': 'Black Friday 2024 ⚡ Ofertas Hoy'},
#  {'question': '¿Qué categorías de productos tienen ofertas?',
#   'answer': 'Moda, Celulares, Tecnología, Electrodomésticos y mucho más',
#   'category': 'Black Friday 2024 ⚡ Ofertas Hoy'},
#  {'question': '¿Qué consolas de videojuegos están en oferta?',
#   'answer': 'Nintendo Switch, Xbox, PS5',
#   'category': 'Black Friday 2024 ⚡ Ofertas Hoy'},
#  {'question': '¿Qué marcas de electrodomésticos están disponibles en las ofertas?',
#   'answer': 'Samsung, Black&Decker, Whirlpool y muchas más',
#   'category': 'Black Friday 2024 ⚡ Ofertas Hoy'},
#  {'question': '¿Qué ventaja ofrece el Black Friday para las compras navideñas?',
#   'answer': 'Te brinda la oportunidad de adelantar tus compras navideñas y evitar el estrés de las aglomeraciones de última hora',
#   'category': 'Black Friday 2024 ⚡ Ofertas Hoy'},
#  {'question': '¿Qué tipo de productos se pueden encontrar en el Black Friday Chile 2024?',
#   'answer': 'Desde las últimas tendencias en tecnología hasta muebles para el hogar y prendas de moda para toda la familia',
#   'category': 'Black Friday 2024 ⚡ Ofertas Hoy'},
#  {'question': '¿Qué evento se menciona en el texto?',
#   'answer': 'Cyber Day 2024',
#   'category': 'Cyber Day 2024 ⚡ Ofertas'},
#  {'question': '¿Qué tipo de promociones se ofrecen en Cyber Day 2024?',
#   'answer': 'grandes sorpresas, promociones y descuentos preparados especialmente para ti',
#   'category': 'Cyber Day 2024 ⚡ Ofertas'},
#  {'question': '¿Dónde se pueden encontrar ofertas todo el año?',
#   'answer': 'en tus marcas favoritas',
#   'category': 'Cyber Day 2024 ⚡ Ofertas'},
#  {'question': '¿Qué se puede encontrar en falabella.com?',
#   'answer': 'las mejores ofertas en iPhones, moda mujer, aire acondicionado, secadoras, parrillas, abrigos mujer y mucho más',
#   'category': 'Cyber Day 2024 ⚡ Ofertas'},
#  {'question': '¿Qué se recomienda descargar para encontrar ofertas increíbles?',
#   'answer': 'la app falabella.com',
#   'category': 'Cyber Day 2024 ⚡ Ofertas'},
#  {'question': '¿Qué debes hacer para recibir ofertas primero?',
#   'answer': 'Activa tus notificaciones',
#   'category': 'Cyber Day 2024 ⚡ Ofertas'},
#  {'question': '¿Qué debes hacer para estar al tanto de todas las ofertas?',
#   'answer': 'Regístrate y actualiza tus datos',
#   'category': 'Cyber Day 2024 ⚡ Ofertas'},
#  {'question': '¿Qué es Falabella?',
#   'answer': 'Falabella es parte del ecosistema del Grupo Falabella y constituye la red de comercialización omnicanal enfocada en moda, tecnología y hogar más importante de Sudamérica.',
#   'category': 'Falabella retail'},
#  {'question': '¿Cuál es el objetivo de Falabella en relación a sus clientes?',
#   'answer': 'Buscamos conectar con nuestros clientes desde diferentes plataformas y canales, potenciando la complementariedad del mundo físico y digital.',
#   'category': 'Falabella retail'},
#  {'question': '¿Cómo contribuye Falabella al crecimiento sostenible de su negocio?',
#   'answer': 'Contribuimos al crecimiento sostenible de nuestro negocio mediante la promoción del cuidado ambiental y el desarrollo social y cultural.',
#   'category': 'Falabella retail'},
#  {'question': '¿Cuántas tiendas por departamento tiene Falabella en Chile, Colombia y Perú?',
#   'answer': '102 tiendas por departamento en Chile, Colombia y Perú.',
#   'category': 'Falabella retail'},
#  {'question': '¿Cuántos colaboradores tiene Falabella en Chile, Colombia y Perú?',
#   'answer': '+ 24 mil colaboradores en Chile, Colombia y Perú.',
#   'category': 'Falabella retail'},
#  {'question': '¿Cuántos clientes tiene Falabella en Chile, Colombia y Perú?',
#   'answer': '+16 millones de clientes en Chile, Colombia y Perú.',
#   'category': 'Falabella retail'},
#  {'question': '¿Cuántas tiendas de Falabella tienen Certificación Leed en Latinoamérica?',
#   'answer': '39 tiendas con Certificación Leed en Latinoamérica.',
#   'category': 'Falabella retail'},
#  {'question': '¿Cuántas marcas propias tiene Falabella?',
#   'answer': '45 marcas propias.',
#   'category': 'Falabella retail'},
#  {'question': '¿Quiénes son falabella.com?',
#   'answer': 'Somos falabella.com',
#   'category': 'Términos y condiciones'},
#  {'question': '¿Cuáles son las condiciones de compra en falabella.com?',
#   'answer': 'Condiciones de tu compra en falabella.com',
#   'category': 'Términos y condiciones'},
#  {'question': '¿Qué se busca con las compras realizadas en falabella.com?',
#   'answer': 'Nuestra prioridad es que te sientas contento y satisfecho con las compras que realizas.',
#   'category': 'Términos y condiciones'},
#  {'question': '¿Qué garantías y beneficios ofrece falabella.com?',
#   'answer': 'Además de las garantías legales y las ofrecidas por los fabricantes y por los Vendedores de los productos que se comercializan en falabella.com, tenemos beneficios adicionales para entregarte una experiencia realmente satisfactoria.',
#   'category': 'Términos y condiciones'},
#  {'question': '¿Qué se explicará en el texto sobre falabella.com?',
#   'answer': 'A continuación, te explicaremos en qué consisten los derechos, garantías y beneficios a los que te puedes acoger al comprar o contratar a través de falabella.com.',
#   'category': 'Términos y condiciones'},
#  {'question': '¿Qué se menciona sobre la seguridad de las compras?',
#   'answer': 'Seguridad de tu compra y propiedad intelectual',
#   'category': 'Términos y condiciones'},
#  {'question': '¿Qué tipo de cookies se utilizan en los sitios web de Falabella?',
#   'answer': 'utilizamos cookies propias o de terceros',
#   'category': 'Políticas de cookies'},
#  {'question': '¿Cuál es uno de los propósitos de utilizar cookies en Falabella?',
#   'answer': 'mejorar nuestros servicios y su funcionamiento, así como para optimizar la experiencia de nuestros usuarios',
#   'category': 'Políticas de cookies'},
#  {'question': '¿Qué tipo de información se elabora con las cookies?',
#   'answer': 'información estadística',
#   'category': 'Políticas de cookies'},
#  {'question': '¿Cómo se personaliza el contenido ofrecido a los usuarios?',
#   'answer': 'en base a un análisis de sus hábitos de navegación',
#   'category': 'Políticas de cookies'},
#  {'question': '¿Cuál es el objetivo de la Política de cookies de Falabella?',
#   'answer': 'ayudarte a comprender cómo y para qué Falabella.com SpA y el resto de las empresas Falabella utilizan las cookies y las opciones que tienes para gestionarlas',
#   'category': 'Políticas de cookies'},
#  {'question': '¿Qué considera la Compañía como parte de su propuesta de valor?',
#   'answer': 'la protección de tus datos personales',
#   'category': 'Políticas de privacidad'},
#  {'question': '¿Qué se explica en este documento?',
#   'answer': 'quién es el responsable del tratamiento de tus datos personales, cuál es la finalidad y legitimación con la que los tratamos, a quién podemos comunicarlos, por cuánto tiempo almacenamos tus datos, cómo y por qué los recabamos, de qué manera los utilizamos, y también te explicamos los procesos que hemos dispuesto para proteger tu privacidad y los derechos que te asisten.',
#   'category': 'Políticas de privacidad'},
#  {'question': "¿Qué comprende el término 'Empresas Falabella'?",
#   'answer': 'Falabella S.A., Servicios e Inversiones Falabella Limitada, Servicios Falabella SpA, Banco Falabella, Promotora CMR Falabella S.A., Banco Falabella Corredores de Seguro Ltda., CF Seguros de Vida S.A., Seguros Falabella Corredores Limitada, Digital Payments SpA, Digital Payments Prepago S.A., Falabella Retail S.A., Sodimac S.A., Hipermercados Tottus S.A, Falabella Inmobiliario S.A., Open Plaza Chile SpA, Plaza S.A., Ikso SpA (Ikea), Promotora Chilena de Café Colombia S.A. (Juan Valdez), Imperial S.A. y Fazil SpA.',
#   'category': 'Políticas de privacidad'},
#  {'question': '¿Con qué se integra la Política de Privacidad?',
#   'answer': 'los Términos y Condiciones de contratación con la Compañía y, en general, de cualquier tipo de relación con la misma.',
#   'category': 'Políticas de privacidad'},
#  {'question': '¿Dónde se puede contactar a la Compañía si hay preguntas u observaciones?',
#   'answer': 'al correo electrónico [email\xa0protected]',
#   'category': 'Políticas de privacidad'}]

# %%
scraper.to_json("../db_knowledge.json")

# %%
url = "https://www.falabella.com/falabella-cl/page/Vende-en-Falabella.com"
response = requests.get(url, timeout=10)  # Add a 30-second timeout
soup = BeautifulSoup(response.text, 'html.parser')

# Extract text content
text_content = soup.get_text(separator='\n', strip=True)
topic = text_content.split('\n')[0].split('|')[0].strip()

# Use LangChain agent to group text
relevant_text = scraper.llm.invoke(f"Extrae del siguiente texto el contenido relacionado con el siguiente tema: {topic}, solamente entrega el texto  \n\n{text_content}").content

# %%
scraper._group_text.args_schema.schema()
# Out:
# {'description': 'Agrupa texto en un JSON con formato question-answer',
#  'properties': {'self': {'title': 'Self'},
#   'text': {'description': 'Texto a agrupar',
#    'title': 'Text',
#    'type': 'string'}},
#  'required': ['self', 'text'],
#  'title': 'Agrupar texto en formato pregunta-respuesta',
#  'type': 'object'}
